# %%
#HOMEWORK
from ingest import load_github_llm_zoomcamp_repo
from gitsource import chunk_documents

documents = load_github_llm_zoomcamp_repo()
print(f"Loaded {len(documents)} documents")

chunks = chunk_documents(documents, size=2000, step=1000)
print(len(chunks))

import time
from sqlitesearch import TextSearchIndex

index = TextSearchIndex(
    text_fields=["content"],
    keyword_fields=["filename"],
    db_path="faq.db"
)

for doc in chunks:
    index.add(doc)
    print(f"""Added: {doc["content"][:60]}...""")
    time.sleep(0.5)

index.close()
print("Done. Index saved to faq.db")
# Out:
# Loaded 72 documents
# 295
# Added: # Introduction
#
# Video: [Watch this lesson](https://www.youtu...
# Added: the next
# word based on what you typed so far.
#
# A large langu...
# Added: wrong.
#
# ## The project
#
# RAG solves these problems by giving ...
# Added: # Environment
#
# Video: [Watch this lesson](https://www.youtub...
# Added: nitialize it:
#
# ```bash
# mkdir llm-zoomcamp-code
# cd llm-zoomca...
# Added:
# The safest way to store the key is in a `.env` file that ne...
# Added: # RAG
#
# Video: [Watch this lesson](https://www.youtube.com/wa...
# Added: ur black box - text goes in, text comes out.
#
# Let's test it:...
# Added: you want to receive a certificate, you need to submit your p...
# Added: we drop it.
#
# Build a prompt that includes both the question ...
# Added: hat the LLM generates.
# That search step is what gives the LL...
# Added: # The Course FAQ Dataset
#
# Video: [Watch this lesson](https:/...
# Added: e FAQ documents from all
# courses:
#
# ```python
# documents = []
# ...
# Added:  `data-engineering-zoomcamp`, etc. We'll
# use these slugs for...
# Added: # Search
#
# Video: [Watch this lesson](https://www.youtube.com...
# Added: ll join the course after the start date?"
# - "Is it possible ...
# Added: arch engine. It's lightweight, so it runs anywhere Python
# ru...
# Added: u learn here transfers directly.
#
# We'll index the `question`...
# Added: achine learning courses mixed in.
#
# ```python
# from minsearch ...
# Added: se are the candidate documents we'll send to the LLM.
#
# We us...
# Added: n the question field now weighs twice what it
# does in the an...
# Added: # Building the Prompt
#
# Video: [Watch this lesson](https://ww...
# Added: to find relevant information and provide accurate
# answers. I...
# Added:  data to the LLM.
#
# ## Building the prompt
#
# Now we combine th...
# Added: # The LLM
#
# Video: [Watch this lesson](https://www.youtube.co...
# Added: t but call `chat.completions` instead of `responses`.
#
# ## Ex...
# Added: .com/api/docs/models/gpt-5.4-mini):
#
# - Input: $0.75 per mill...
# Added: fter that, your
# messages and the LLM's replies alternate. Th...
# Added: ow put this together into an updated `llm` function.
#
# It now...
# Added: # RAG Helper
#
# Video: [Watch this lesson](https://www.youtube...
# Added: ents = []
#     url_prefix = "https://datatalks.club/faq"
#
#    ...
# Added: port them back, but that ties the file
# to one specific index...
# Added: ROMPT_TEMPLATE,
#         course="llm-zoomcamp",
#         model...
# Added:   )
# ```
#
# The `build_context` and `build_prompt` methods form...
# Added: put_text
# ```
#
# And the `rag` method wires it all together:
#
# `...
# Added: # Data Ingestion
#
# Video: [Watch this lesson](https://www.you...
# Added: hare the index between them.
#
# The index survives restarts, s...
# Added: ightweight).
#
# Install it:
#
# ```bash
# uv add sqlitesearch
# ```
#
# ...
# Added:  index.add(doc)
#     print(f"""Added: {doc["question"][:60]}....
# Added:  at the same
# time. With minsearch this is impossible, becaus...
# Added:  But now the
# data comes from a persistent index - no fetchin...
# Added: lowchart TD
#
#     subgraph ING["INGESTION"]
#         direction...
# Added: osing an approach
#
# Pick the right tool for your data:
#
# - `mi...
# Added: # Wrap-up of Part 1
#
# Video: [Watch this lesson](https://www....
# Added: ches to
# run, and when to stop.
#
# An agent also handles questi...
# Added: ine-tune
# the LLM on your data.
#
# Fine-tuning means taking a m...
# Added: # Agents
#
# Video: [Watch this lesson](https://www.youtube.com...
# Added: # Quick RAG Revision (Optional)
#
# Video: [Watch this lesson](...
# Added: ithubusercontent.com/DataTalksClub/llm-zoomcamp/main/01-agen...
# Added: # Function Calling
#
# Video: [Watch this lesson](https://www.y...
# Added: decides when to call it and what to search for.
#
# The same ty...
# Added:  see what the LLM does without any tools. We ask it a
# course...
# Added:  num_results=5,
#         boost_dict=boost_dict,
#         filte...
# Added:  function. `parameters` is a JSON schema
# for the arguments, ...
# Added: unction, and serialize the result.
#
# ```python
# import json
#
# c...
# Added: its own decision to
# call `search`, and the FAQ results. It c...
# Added: ```python
# usage = response.usage
# usage.input_tokens, usage.o...
# Added: # The Agentic Loop
#
# Video: [Watch this lesson](https://www.y...
# Added: h`.
# - Memory, the message history. We append every prompt, e...
# Added: ther areas that the user wants to explore.
# """.strip()
# ```
#
# ...
# Added: s.
# Function-call results get appended too.
#
# ```python
# questi...
# Added: while` loop. The loop keeps calling the model until
# it retur...
# Added: ees the result on the next turn.
# The loop stops when the mod...
# Added:     has_function_calls = False
#
#         response = openai_cl...
# Added: llama" and finds the answer.
# The loop lets the model recover...
# Added: trip()
#
# agent_loop(instructions, "I just discovered the cour...
# Added:  the user question as possible when making first requests.
#
# ...
# Added: # ToyAIKit
#
# Video: [Watch this lesson](https://www.youtube.c...
# Added: ant for production use. We use it because it's minimal and y...
# Added:  num_results=5,
#         boost_dict={"question": 3.0, "sectio...
# Added:    developer_prompt=instructions,
#     chat_interface=chat_in...
# Added: esult.
#
# The `result` is a `LoopResult` with `all_messages` (...
# Added: # Other Frameworks
#
# Video: [Watch this lesson](https://www.y...
# Added: ramework that supports multiple LLM providers.
# Tools are pla...
# Added: s on Google Cloud or you specifically want
# Gemini.
#
# ## Other...
# Added: # Vector Search
#
# Video: [Watch this lesson](https://www.yout...
# Added: dding model produces these vectors. It's a neural network
# tr...
# Added: ch uses an inverted index (BM25, TF-IDF). Vector search
#   us...
# Added: # Embeddings
#
# Video: [Watch this lesson](https://www.youtube...
# Added: ar away from Q1 and Q2.
# ```
#
# Now imagine all 1200 documents ...
# Added: ``bash
# uv add sentence-transformers
# ```
#
# This also pulls in ...
# Added: thing the
# model can read. After that, both load from a local...
# Added: get 0.01.
#
# The first score for `q1` vs `d` (0.32) is higher,...
# Added: # Embedding Our Dataset
#
# Video: [Watch this lesson](https://...
# Added:
#
# Now we generate the embeddings. We have about 1200 texts h...
# Added: # Vector Search
#
# Video: [Watch this lesson](https://www.yout...
# Added: ode instead
# of looping in Python, so the matrix version is h...
# Added: e reverse them to get the highest
# first:
#
# ```python
# top5 = t...
# Added: # Vector Search with minsearch
#
# Video: [Watch this lesson](h...
# Added: ourse"])
# vindex.fit(X, documents)
# ```
#
# We pass the numpy arr...
# Added: # RAG with Vector Search
#
# Video: [Watch this lesson](https:/...
# Added: w.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/01-a...
# Added: rch takes the query string
# directly, but vector search needs...
# Added: # Vector Search with sqlitesearch
#
# Video: [Watch this lesson...
# Added: rch. We score
# the query against every document and pick the ...
# Added: em back.
#
# If you didn't install it in the previous module, a...
# Added: works the same way as with minsearch. We always encode the q...
# Added: ex = VectorSearchIndex(
#     keyword_fields=["course"],
#     m...
# Added: thon
# from sentence_transformers import SentenceTransformer
# f...
# Added:            filter_dict=filter_dict
#         )
#
# vector_assista...
# Added: # Vector Search with PGVector
#
# Video: [Watch this lesson](ht...
# Added: ar/lib/postgresql/data \
#     -p 5432:5432 \
#     pgvector/pgv...
# Added:  = model.encode(batch)
#     vectors.extend(batch_vectors)
# ```...
# Added: PGVector:
#
# ```python
# def vec_to_str(vector):
#     return "[" ...
# Added: n, answer,
#            1 - (embedding <=> %s::vector) AS simi...
# Added: switch to approximate search:
#
# ```python
# conn.execute("""
#   ...
# Added: gvector_search("How do I join the course?")
# ```
#
# ## Using it...
# Added: .fetchall()
#
#         return [
#             {"course": r[0], "...
# Added: # Using ONNX Runtime instead of PyTorch
#
# Video: [Watch this ...
# Added: s lesson:
#
# ```bash
# mkdir llm-zoomcamp-onnx && cd llm-zoomcam...
# Added: cript from the
# `embed/` directory for generating embeddings....
# Added:  embed.encode(q1)
# v2 = embed.encode(q2)
# dv = embed.encode(d)...
# Added: (batch_vectors)
#
# X = np.array(X)
# ```
#
# And search:
#
# ```python...
# Added: # Next Steps
#
# Video: [Watch this lesson](https://www.youtube...
# Added: w of them come from companies that sell vector databases. So...
# Added: # AI Orchestration
#
# Video: [Using AI in Workflows](https://y...
# Added: e Cloud account with access to Gemini API
# - Basic understand...
# Added: # Context Engineering
#
# Video: [Using AI in Workflows](https:...
# Added: # Setting up Kestra
#
# Video: [Setting up Kestra](https://yout...
# Added: ient for light use, but rate limits are relatively low — you...
# Added:  SECRET_OPENAI_API_KEY=$(echo -n "your-openai-api-key-here" ...
# Added: # AI Copilot
#
# Video: [AI Copilot](https://youtu.be/OTiOdt17h...
# Added: stra's Open Source edition, the AI Copilot only supports Gem...
# Added: ou to a working flow quickly, but it won't know everything a...
# Added: n if it fails" → Copilot adds a `SlackIncomingWebhook` task ...
# Added: # Retrieval Augmented Generation
#
# Video: [RAG Workflows](htt...
# Added: arch](../../02-vector-search/lessons/04-vector-search.md).
#
# ...
# Added: ale demos, but it is not a replacement for a proper vector d...
# Added: be accurate.
#
# ### Step 2: With RAG
#
# Flow: [`2_chat_with_rag....
# Added: t
# > 2. Go to API keys and create a new key
# > 3. Export it as...
# Added: # AI Agents
#
# Video: [Agentic Workflows](https://youtu.be/7tv...
# Added: f supported providers](https://kestra.io/plugins/plugin-ai/p...
# Added: nt.AIAgent
#
#     # Defines the agent's role and behavior
#     ...
# Added: token usage for cost monitoring.
#
# ## Advanced Agent Example:...
# Added:  | Run code safely via Judge0 | Math calculations, data vali...
# Added: # Multi-Agent Systems
#
# Video: [Agentic Workflows](https://yo...
# Added: # Best Practices
#
# ## When to Use What
#
# | Scenario | Use This...
# Added: | Batch / Flex | $0.75 | $4.50 |
# | Gemini 3.5 Flash | Priori...
# Added: /docs/concepts/secret).
#
# ## Observability and Debugging
#
# Ena...
# Added: # Next Steps
#
# In this module, we covered:
#
# - Why context eng...
# Added: e a workflow you already run and ask: which parts involve de...
# Added: # Evaluation
#
# Video: [Watch this lesson](https://www.youtube...
# Added: document is the correct answer. We'll use an LLM to generate...
# Added:  Offline evaluation: run the system on a test dataset and co...
# Added: # Generating Ground Truth Data
#
# Video: [Watch this lesson](h...
# Added: swer.
#
# ## Loading the documents
#
# We'll use helper files from...
# Added: python
# doc = documents[0]
# print(doc["id"])
# print(doc["questi...
# Added: the output. The model returns the
# same structure every time....
# Added:
# Call the LLM for one document:
#
# ```python
# from dotenv impor...
# Added: the first FAQ document.
#
# ## Reusable utilities
#
# We'll need t...
# Added: we calculate the price from `response.usage`.
#
# Import the pr...
# Added: # Generating Ground Truth for All Documents
#
# Video: [Watch t...
# Added: s, one of them might fail. We don't want the
# entire batch to...
# Added:  in tqdm(documents[:5]):
#     records, usage = generate_groun...
# Added: futures, ask ChatGPT to walk
# through this helper line by lin...
# Added: _price(usages)
# ```
#
# Create a dataframe so we can look at the...
# Added: # Search Evaluation
#
# Video: [Watch this lesson](https://www....
# Added: data, build_index
#
# documents = load_faq_data()
#
# documents_ll...
# Added: ery=q["question"])
# ```
#
# First, compare the retrieved documen...
# Added: ocument was the first search result.
#
# Here are two more exam...
# Added: relevance_total_text
# ```
#
# For the data we prepared on May 29...
# Added: # Search Evaluation Metrics
#
# Video: [Watch this lesson](http...
# Added: k mean the same thing.
#
# Let's calculate it:
#
# ```python
# cnt =...
# Added: wer in the list.
#
# Look at that line:
#
# ```python
# example[1]
# #...
# Added: ore = 0.0
#
#     for line in relevance:
#         for rank in ra...
# Added:  ground truth assumes only one relevant document per query. ...
# Added: # Search Parameter Tuning
#
# Video: [Watch this lesson](https:...
# Added: : question_boost, "section": 0.5}
#
#     return index.search(
# ...
# Added:  parameter. We can also tune `answer` and `section`
# together...
# Added: t: search_boosts(
#                     query,
#                ...
# Added:      2.0     0.5      0.965     0.862
# 1.0       4.0     0.1 ...
# Added:         num_results=5,
#         boost_dict=boost_dict,
#     )
# ...
# Added: # RAG and Agent Evaluation
#
# Video: [Watch this lesson](https...
# Added: r, and also save the tool
# calls. Then we can look at whether...
# Added: # Generating RAG Answers
#
# Video: [Watch this lesson](https:/...
# Added: truth-new.csv")
# ground_truth = df_ground_truth.to_dict(orien...
# Added:
#
# It also uses the search boosts we selected in the search t...
# Added: # Processing all questions
#
# Create a function that processes...
# Added: ogress
# ```
#
# Run RAG for all ground truth questions:
#
# ```pyth...
# Added: # LLM as a Judge
#
# Video: [Watch this lesson](https://www.you...
# Added:  pass:
#
# - search: did we retrieve context that contains the ...
# Added: enerated answer. In this lesson, we use the
# stronger offline...
# Added: ent
# 2. The original answer from the FAQ (ground truth)
# 3. An...
# Added:  = answers[0]
# ```
#
# Create the judge prompt:
#
# ```python
# promp...
# Added: nswer_orig"],
#     answer_llm=rec["answer_llm"]
# )
#
# eval_resul...
# Added:
# calc_total_price(usages)
# ```
#
# Check the results:
#
# ```python...
# Added:  use another judge to evaluate the
# judge. This is manual wor...
# Added: # Agent Evaluation
#
# Video: [Watch this lesson](https://www.y...
# Added:  build_index(documents)
# ```
#
# Create a lookup table:
#
# ```pyth...
# Added: hing assistant. Answer student questions based on
# the FAQ se...
# Added: nd({
#                 "name": message.name,
#                 "...
# Added: ultiple questions
#
# Create a function that processes one grou...
# Added:
# ```
#
# Save the results:
#
# ```python
# df_agent.to_csv("data/age...
# Added: one
# place.
#
# ## Judging answers and trajectories
#
# A good traj...
# Added:
#     )
#     answer_score: Literal["good", "bad"] = Field(
#    ...
# Added: id the agent avoid duplicate or unnecessary tool calls?
# - If...
# Added: r_orig"],
#         answer_agent=rec["answer_agent"],
#         ...
# Added: ent_eval.answer_score,
#         "answer_reasoning": agent_eva...
# Added: # Next Steps
#
# Video: [Watch this lesson](https://www.youtube...
# Added:  from
#    your FAQ or documentation. This gives you a baselin...
# Added: ion
# set up yet.
#
# ## Evaluation frameworks
#
# For production sy...
# Added: # Monitoring
#
# Video: [Watch this lesson](https://www.youtube...
# Added: # Assistant
#
# Video: [Watch this lesson](https://www.youtube....
# Added: tic-rag/code/ingest.py
# wget ${PREFIX}/01-agentic-rag/code/ra...
# Added: # Chat App
#
# Video: [Watch this lesson](https://www.youtube.c...
# Added: # Capturing Metrics
#
# Video: [Watch this lesson](https://www....
# Added: kens: int
#     response_time: float
#     cost: float
#     times...
# Added: s it and only
# change the one method that calls the LLM. Ever...
# Added: pt}
#         ]
#         response = self.llm_client.responses.c...
# Added: nput_tokens,
#             completion_tokens=usage.output_toke...
# Added: # Storing Data in PostgreSQL
#
# Video: [Watch this lesson](htt...
# Added: 5432 \
#     -v pgdata:/var/lib/postgresql/data \
#     postgres...
# Added: r:
#
# ```bash
# uv add "psycopg[binary]"
# ```
#
# ## Initializing th...
# Added: ons TEXT NOT NULL,
#     prompt TEXT NOT NULL,
#     prompt_toke...
# Added: he table. With `drop=True` it drops the table
# first, which w...
# Added:   response_time FLOAT NOT NULL,
#                     cost FLO...
# Added: ersations (
#     question, answer, course, model, instruction...
# Added:           cur.execute(
#                 """
#                 I...
# Added: )
#     finally:
#         conn.close()
#     return conversation_...
# Added: # Querying Data
#
# Video: [Watch this lesson](https://www.yout...
# Added: (
#         model=row[4],
#         prompt=row[6],
#         instr...
# Added: # Streamlit Dashboard
#
# Video: [Watch this lesson](https://ww...
# Added:  a `Stats` dataclass to `db_query.py`:
#
# ```python
# @dataclass...
# Added: re getting started. You can show far more, but these are a g...
# Added: # User Feedback
#
# Video: [Watch this lesson](https://www.yout...
# Added: LLM judge. So we use
# one feedback table with a `source` colu...
# Added:  initialized")
# ```
#
# Re-run the init script:
#
# ```bash
# uv run ...
# Added:           explanation, score, timestamp),
#             )
#     ...
# Added:
#         st.write(f"Cost: ${record.cost:.4f}")
#
#         conv...
# Added: # Built-in Judge
#
# Video: [Watch this lesson](https://www.you...
# Added: parse.
#
# We need `evaluation_utils` from module 04.
#
# Download...
# Added: planation` field matters even though we don't always do anyt...
# Added:      prompt,
#         RelevanceVerdict,
#     )
#
#     return res...
# Added: back to the database
#
# We already created the `feedback` tabl...
# Added:              relevance=relevance, explanation=explanation)
# s...
# Added: # Feedback Dashboard
#
# _This lesson has no video._
#
# We collec...
# Added:  > 0 THEN 1 ELSE 0 END),
#                     SUM(CASE WHEN s...
# Added: # Synthetic Data Generation
#
# _This lesson has no video._
#
# A ...
# Added: r Desktop from the official website.",
#     "Yes, you can joi...
# Added: simulate that most users are happy with the answers:
#
# ```pyt...
# Added: # Grafana Dashboards
#
# Video: [Watch this lesson](https://www...
# Added: ed with `-d`. If you'd rather watch
# its logs while you set t...
# Added:  to place points on the x-axis, so a
# time chart needs it. Se...
# Added:  token consumption over time.
#
# Over a long time range there ...
# Added: nel
#
# Shows which models are being used:
#
# ```sql
# SELECT
#   mod...
# Added: # Docker Compose
#
# _This lesson has no video._
#
# By now we hav...
# Added: IR /app
# ENV PATH="/app/.venv/bin:$PATH"
#
# COPY pyproject.toml...
# Added: # Next Steps
#
# Video: [Watch this lesson](https://www.youtube...
# Added: ngfuse.com/) and
#   [Arize Phoenix](https://phoenix.arize.com...
# Added: n't slow down the user's request. You capture into a queue a...
# Added: # Best Practices for RAG
#
# In the previous modules we built s...
# Added: # Hybrid Search
#
# Vector search finds documents by semantic m...
# Added: = 0.500 + 0.167 = 0.667
#   B = 1/(1+1+1) + 1/(1+1+1) = 0.333 ...
# Added: # Document Reranking
#
# When we retrieve documents, they're ra...
# Added: ,
#         "num_candidates": 10000,
#         "boost": 0.5,
#    ...
# Added: n error.
#
# ## Implementing RRF ourselves
#
# We can implement RR...
# Added:
#     knn_response = es_client.search(
#         index=index_na...
# Added: s in both search results, its RRF
# scores are summed, giving ...
# Added: # Hybrid Search with LangChain
#
# So far we've been working wi...
# Added: es keyword and vector search:
#
# ```python
# def hybrid_query(se...
# Added: ,
#     body_func=hybrid_query,
#     content_field="text"
# )
# ```...
# Added:        "term": {
#                             "course": cours...
# Added: # Next Steps
#
# In this module, we covered hybrid search and d...
# Added: # End-to-End Project Example
#
# <a href="https://www.youtube.c...
# Added: nt
# cd fitness-assistant
# uv init
# uv add openai minsearch requ...
# Added: part: str = Field(description="Chest, Back, Legs, etc.")
#    ...
# Added: csv", index=False)
# print(f"Generated {len(df)} exercises")
# `...
# Added: tor. Answer the QUESTION based on the CONTEXT from our exerc...
# Added: # Evaluating Retrieval
#
# <a href="https://www.youtube.com/wat...
# Added:  LLM, asking it to create questions for each exercise:
#
# ```p...
# Added: ions.to_csv("data/ground-truth-retrieval.csv", index=False)
# ...
# Added: nce)
#     return {
#         "hit_rate": hit_rate(relevance_tot...
# Added: arams = None
#     best_score = float("-inf")
#
#     for _ in ra...
# Added: # Evaluating RAG
#
# <a href="https://www.youtube.com/watch?v=l...
# Added: rovide your evaluation in parsable JSON without using code b...
# Added: apply(lambda d: d["question"])
# df_eval["relevance"] = df_eva...
# Added: # Interface and Ingestion Pipeline
#
# <a href="https://www.you...
# Added: ndex.
#
# Since minsearch is in-memory, ingestion happens when ...
# Added: )
#
# def search(query):
#     boost = {
#         "exercise_name":...
# Added: ext = ""
#     for doc in search_results:
#         context = co...
# Added:     "prompt_tokens": token_stats["prompt_tokens"],
#         "...
# Added: # Monitoring and Containerization
#
# <a href="https://www.yout...
# Added: wer: {answer}
#
# Please analyze the content and context of the...
# Added: pletion_tokens"] * 0.60
#         ) / 1_000_000
#     return ope...
# Added:    "total_tokens": token_stats["total_tokens"],
#         "eva...
# Added:
#     try:
#         with conn.cursor() as cur:
#             cur...
# Added: OT NULL
#                 )
#             """)
#             cur.e...
# Added: al_completion_tokens, eval_total_tokens,
#                 ope...
# Added: ()
# ```
#
# And a function to record user feedback:
#
# ```python
# d...
# Added: stion)
#
#     db.save_conversation(
#         conversation_id=co...
# Added:  services:
#
# ```yaml
# services:
#   postgres:
#     image: postgre...
# Added: # Summary and Closing Remarks
#
# <a href="https://www.youtube....
# Added: gging: ~$0.50
#
# Using GPT-4o-mini keeps costs low. You could ...
# Added: # Chunking for Longer Texts
#
# <a href="https://www.youtube.co...
# Added: c.
#
# ):
#
# 1. Split it into chunks
# 2. Evaluate the same way as ...
# Done. Index saved to faq.db

# %%
from ingest import load_faq_data

documents = load_faq_data()
print(f"Loaded {len(documents)} documents")

docs_llm = [doc for doc in documents if doc["course"] == "llm-zoomcamp"]
print(f"LLM Zoomcamp: {len(docs_llm)} documents")

import time
from sqlitesearch import TextSearchIndex

index = TextSearchIndex(
    text_fields=["question", "section", "answer"],
    keyword_fields=["course"],
    db_path="faq.db"
)

for doc in docs_llm:
    index.add(doc)
    print(f"""Added: {doc["question"][:60]}...""")
    time.sleep(0.5)

index.close()
print("Done. Index saved to faq.db")
# Out:
# Loaded 72 documents
# Added: # Introduction
#
# Video: [Watch this lesson](https://www.youtu...
# Added: # Environment
#
# Video: [Watch this lesson](https://www.youtub...
# Added: # RAG
#
# Video: [Watch this lesson](https://www.youtube.com/wa...
# Added: # The Course FAQ Dataset
#
# Video: [Watch this lesson](https:/...
# Added: # Search
#
# Video: [Watch this lesson](https://www.youtube.com...
# Added: # Building the Prompt
#
# Video: [Watch this lesson](https://ww...
# Added: # The LLM
#
# Video: [Watch this lesson](https://www.youtube.co...
# Added: # RAG Helper
#
# Video: [Watch this lesson](https://www.youtube...
# Added: # Data Ingestion
#
# Video: [Watch this lesson](https://www.you...
# Added: # Wrap-up of Part 1
#
# Video: [Watch this lesson](https://www....
# Added: # Agents
#
# Video: [Watch this lesson](https://www.youtube.com...
# Added: # Quick RAG Revision (Optional)
#
# Video: [Watch this lesson](...
# Added: # Function Calling
#
# Video: [Watch this lesson](https://www.y...
# Added: # The Agentic Loop
#
# Video: [Watch this lesson](https://www.y...
# Added: # ToyAIKit
#
# Video: [Watch this lesson](https://www.youtube.c...
# Added: # Other Frameworks
#
# Video: [Watch this lesson](https://www.y...
# Added: # Vector Search
#
# Video: [Watch this lesson](https://www.yout...
# Added: # Embeddings
#
# Video: [Watch this lesson](https://www.youtube...
# Added: # Embedding Our Dataset
#
# Video: [Watch this lesson](https://...
# Added: # Vector Search
#
# Video: [Watch this lesson](https://www.yout...
# Added: # Vector Search with minsearch
#
# Video: [Watch this lesson](h...
# Added: # RAG with Vector Search
#
# Video: [Watch this lesson](https:/...
# Added: # Vector Search with sqlitesearch
#
# Video: [Watch this lesson...
# Added: # Vector Search with PGVector
#
# Video: [Watch this lesson](ht...
# Added: # Using ONNX Runtime instead of PyTorch
#
# Video: [Watch this ...
# Added: # Next Steps
#
# Video: [Watch this lesson](https://www.youtube...
# Added: # AI Orchestration
#
# Video: [Using AI in Workflows](https://y...
# Added: # Context Engineering
#
# Video: [Using AI in Workflows](https:...
# Added: # Setting up Kestra
#
# Video: [Setting up Kestra](https://yout...
# Added: # AI Copilot
#
# Video: [AI Copilot](https://youtu.be/OTiOdt17h...
# Added: # Retrieval Augmented Generation
#
# Video: [RAG Workflows](htt...
# Added: # AI Agents
#
# Video: [Agentic Workflows](https://youtu.be/7tv...
# Added: # Multi-Agent Systems
#
# Video: [Agentic Workflows](https://yo...
# Added: # Best Practices
#
# ## When to Use What
#
# | Scenario | Use This...
# Added: # Next Steps
#
# In this module, we covered:
#
# - Why context eng...
# Added: # Evaluation
#
# Video: [Watch this lesson](https://www.youtube...
# Added: # Generating Ground Truth Data
#
# Video: [Watch this lesson](h...
# Added: # Generating Ground Truth for All Documents
#
# Video: [Watch t...
# Added: # Search Evaluation
#
# Video: [Watch this lesson](https://www....
# Added: # Search Evaluation Metrics
#
# Video: [Watch this lesson](http...
# Added: # Search Parameter Tuning
#
# Video: [Watch this lesson](https:...
# Added: # RAG and Agent Evaluation
#
# Video: [Watch this lesson](https...
# Added: # Generating RAG Answers
#
# Video: [Watch this lesson](https:/...
# Added: # LLM as a Judge
#
# Video: [Watch this lesson](https://www.you...
# Added: # Agent Evaluation
#
# Video: [Watch this lesson](https://www.y...
# Added: # Next Steps
#
# Video: [Watch this lesson](https://www.youtube...
# Added: # Monitoring
#
# Video: [Watch this lesson](https://www.youtube...
# Added: # Assistant
#
# Video: [Watch this lesson](https://www.youtube....
# Added: # Chat App
#
# Video: [Watch this lesson](https://www.youtube.c...
# Added: # Capturing Metrics
#
# Video: [Watch this lesson](https://www....
# Added: # Storing Data in PostgreSQL
#
# Video: [Watch this lesson](htt...
# Added: # Querying Data
#
# Video: [Watch this lesson](https://www.yout...
# Added: # Streamlit Dashboard
#
# Video: [Watch this lesson](https://ww...
# Added: # User Feedback
#
# Video: [Watch this lesson](https://www.yout...
# Added: # Built-in Judge
#
# Video: [Watch this lesson](https://www.you...
# Added: # Feedback Dashboard
#
# _This lesson has no video._
#
# We collec...
# Added: # Synthetic Data Generation
#
# _This lesson has no video._
#
# A ...
# Added: # Grafana Dashboards
#
# Video: [Watch this lesson](https://www...
# Added: # Docker Compose
#
# _This lesson has no video._
#
# By now we hav...
# Added: # Next Steps
#
# Video: [Watch this lesson](https://www.youtube...
# Added: # Best Practices for RAG
#
# In the previous modules we built s...
# Added: # Hybrid Search
#
# Vector search finds documents by semantic m...
# Added: # Document Reranking
#
# When we retrieve documents, they're ra...
# Added: # Hybrid Search with LangChain
#
# So far we've been working wi...
# Added: # Next Steps
#
# In this module, we covered hybrid search and d...
# Added: # End-to-End Project Example
#
# <a href="https://www.youtube.c...
# Added: # Evaluating Retrieval
#
# <a href="https://www.youtube.com/wat...
# Added: # Evaluating RAG
#
# <a href="https://www.youtube.com/watch?v=l...
# Added: # Interface and Ingestion Pipeline
#
# <a href="https://www.you...
# Added: # Monitoring and Containerization
#
# <a href="https://www.yout...
# Added: # Summary and Closing Remarks
#
# <a href="https://www.youtube....
# Added: # Chunking for Longer Texts
#
# <a href="https://www.youtube.co...
# Done. Index saved to faq.db
